# %%
from __future__ import print_function
# %load_ext autoreload
# %autoreload 2
import os
if not os.path.exists('plots/'):
    os.mkdir('plots')

from six.moves import cPickle
from collections import defaultdict, OrderedDict

import numpy as np
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()
K = tf.keras.backend 

import kde
import simplebinmi

# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import seaborn as sns
sns.set_style('darkgrid')

import utils

# load data network was trained on
trn, tst = utils.get_IB_data('2017_12_21_16_51_3_275766')

# calc MI for train and test. Save_activations must have been run with cfg['FULL_MI'] = True
FULL_MI = True

# Which measure to plot
infoplane_measure = 'upper'
# infoplane_measure = 'bin'

DO_SAVE        = True    # Whether to save plots or just show them
DO_LOWER       = (infoplane_measure == 'lower')   # Whether to compute lower bounds also
DO_BINNED      = (infoplane_measure == 'bin')     # Whether to compute MI estimates based on binning

MAX_EPOCHS = 10000      # Max number of epoch for which to compute mutual information measure
NUM_LABELS = 2
# MAX_EPOCHS = 1000
COLORBAR_MAX_EPOCHS = 10000

# Directories from which to load saved layer activity
# ARCH = '1024-20-20-20'
ARCH = '10-7-5-4-3'
#ARCH = '20-20-20-20-20-20'
#ARCH = '32-28-24-20-16-12'
#ARCH = '32-28-24-20-16-12-8-8'
DIR_TEMPLATE = '%%s_%s'%ARCH

# Functions to return upper and lower bounds on entropy of layer activity
noise_variance = 1e-3                    # Added Gaussian noise variance
binsize = 0.07                           # size of bins for binning method
Klayer_activity = K.placeholder(ndim=2)  # Keras placeholder 
entropy_func_upper = K.function([Klayer_activity,], [kde.entropy_estimator_kl(Klayer_activity, noise_variance),])
entropy_func_lower = K.function([Klayer_activity,], [kde.entropy_estimator_bd(Klayer_activity, noise_variance),])

# nats to bits conversion factor
nats2bits = 1.0/np.log(2) 

# Save indexes of tests data for each of the output classes
saved_labelixs = {}

y = tst.y
Y = tst.Y
if FULL_MI:
    full = utils.construct_full_dataset(trn,tst)
    y = full.y
    Y = full.Y

for i in range(NUM_LABELS):
    saved_labelixs[i] = y == i

labelprobs = np.mean(Y, axis=0)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.8/dist-packages/tensorflow/python/compat/v2_compat.py:96: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
PLOT_LAYERS    = None     # Which layers to plot.  If None, all saved layers are plotted 

# Data structure used to store results
measures = OrderedDict()
measures['tanh'] = {}
measures['relu'] = {}
measures['linear'] = {}
measures['linear_Batch'] = {}
# measures['softsign'] = {}
# measures['softplus'] = {}

# %% [markdown]
# Compute MI measures
# -----

# %%
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        print("Directory %s not found" % cur_dir)
        continue
        
    # Load files saved during each epoch, and compute MI measures of the activity in that epoch
    print('*** Doing %s ***' % cur_dir)
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        fname = cur_dir + "/" + epochfile
        with open(fname, 'rb') as f:
            d = cPickle.load(f)

        epoch = d['epoch']
        if epoch in measures[activation]: # Skip this epoch if its already been processed
            continue                      # this is a trick to allow us to rerun this cell multiple times)
            
        if epoch > MAX_EPOCHS:
            continue

        print("Doing", fname)
        
        num_layers = len(d['data']['activity_tst'])

        if PLOT_LAYERS is None:
            PLOT_LAYERS = []
            for lndx in range(num_layers):
                #if d['data']['activity_tst'][lndx].shape[1] < 200 and lndx != num_layers - 1:
                PLOT_LAYERS.append(lndx)
                
        cepochdata = defaultdict(list)
        for lndx in range(num_layers):
            activity = d['data']['activity_tst'][lndx]

            # Compute marginal entropies
            h_upper = entropy_func_upper([activity,])[0]
            if DO_LOWER:
                h_lower = entropy_func_lower([activity,])[0]
                
            # Layer activity given input. This is simply the entropy of the Gaussian noise
            hM_given_X = kde.kde_condentropy(activity, noise_variance)

            # Compute conditional entropies of layer activity given output
            hM_given_Y_upper=0.
            for i in range(NUM_LABELS):
                hcond_upper = entropy_func_upper([activity[saved_labelixs[i],:],])[0]
                hM_given_Y_upper += labelprobs[i] * hcond_upper
                
            if DO_LOWER:
                hM_given_Y_lower=0.
                for i in range(NUM_LABELS):
                    hcond_lower = entropy_func_lower([activity[saved_labelixs[i],:],])[0]
                    hM_given_Y_lower += labelprobs[i] * hcond_lower
                
            cepochdata['MI_XM_upper'].append( nats2bits * (h_upper - hM_given_X) )
            cepochdata['MI_YM_upper'].append( nats2bits * (h_upper - hM_given_Y_upper) )
            cepochdata['H_M_upper'  ].append( nats2bits * h_upper )

            pstr = 'upper: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_upper'][-1], cepochdata['MI_YM_upper'][-1])
            if DO_LOWER:  # Compute lower bounds
                cepochdata['MI_XM_lower'].append( nats2bits * (h_lower - hM_given_X) )
                cepochdata['MI_YM_lower'].append( nats2bits * (h_lower - hM_given_Y_lower) )
                cepochdata['H_M_lower'  ].append( nats2bits * h_lower )
                pstr += ' | lower: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_lower'][-1], cepochdata['MI_YM_lower'][-1])

            if DO_BINNED: # Compute binned estimates
                binxm, binym = simplebinmi.bin_calc_information2(saved_labelixs, activity, binsize)
                cepochdata['MI_XM_bin'].append( nats2bits * binxm )
                cepochdata['MI_YM_bin'].append( nats2bits * binym )
                pstr += ' | bin: MI(X;M)=%0.3f, MI(Y;M)=%0.3f' % (cepochdata['MI_XM_bin'][-1], cepochdata['MI_YM_bin'][-1])
                        
#             print('- Layer %d %s' % (lndx, pstr) )

        measures[activation][epoch] = cepochdata
# Out:
# *** Doing rawdata/tanh_10-7-5-4-3 ***
# Doing rawdata/tanh_10-7-5-4-3/epoch00000000
# Doing rawdata/tanh_10-7-5-4-3/epoch00000001
# Doing rawdata/tanh_10-7-5-4-3/epoch00000002
# Doing rawdata/tanh_10-7-5-4-3/epoch00000003
# Doing rawdata/tanh_10-7-5-4-3/epoch00000004
# Doing rawdata/tanh_10-7-5-4-3/epoch00000005
# Doing rawdata/tanh_10-7-5-4-3/epoch00000006
# Doing rawdata/tanh_10-7-5-4-3/epoch00000007
# Doing rawdata/tanh_10-7-5-4-3/epoch00000008
# Doing rawdata/tanh_10-7-5-4-3/epoch00000009
# Doing rawdata/tanh_10-7-5-4-3/epoch00000010
# Doing rawdata/tanh_10-7-5-4-3/epoch00000011
# Doing rawdata/tanh_10-7-5-4-3/epoch00000012
# Doing rawdata/tanh_10-7-5-4-3/epoch00000013
# Doing rawdata/tanh_10-7-5-4-3/epoch00000014
# Doing rawdata/tanh_10-7-5-4-3/epoch00000015
# Doing rawdata/tanh_10-7-5-4-3/epoch00000016
# Doing rawdata/tanh_10-7-5-4-3/epoch00000017
# Doing rawdata/tanh_10-7-5-4-3/epoch00000018
# Doing rawdata/tanh_10-7-5-4-3/epoch00000019
# Doing rawdata/tanh_10-7-5-4-3/epoch00000020
# Doing rawdata/tanh_10-7-5-4-3/epoch00000025
# Doing rawdata/tanh_10-7-5-4-3/epoch00000030
# Doing rawdata/tanh_10-7-5-4-3/epoch00000035
# Doing rawdata/tanh_10-7-5-4-3/epoch00000040
# Doing rawdata/tanh_10-7-5-4-3/epoch00000045
# Doing rawdata/tanh_10-7-5-4-3/epoch00000050
# Doing rawdata/tanh_10-7-5-4-3/epoch00000055
# Doing rawdata/tanh_10-7-5-4-3/epoch00000060
# Doing rawdata/tanh_10-7-5-4-3/epoch00000065
# Doing rawdata/tanh_10-7-5-4-3/epoch00000070
# Doing rawdata/tanh_10-7-5-4-3/epoch00000075
# Doing rawdata/tanh_10-7-5-4-3/epoch00000080
# Doing rawdata/tanh_10-7-5-4-3/epoch00000085
# Doing rawdata/tanh_10-7-5-4-3/epoch00000090
# Doing rawdata/tanh_10-7-5-4-3/epoch00000095
# Doing rawdata/tanh_10-7-5-4-3/epoch00000100
# Doing rawdata/tanh_10-7-5-4-3/epoch00000120
# Doing rawdata/tanh_10-7-5-4-3/epoch00000140
# Doing rawdata/tanh_10-7-5-4-3/epoch00000160
# Doing rawdata/tanh_10-7-5-4-3/epoch00000180
# Doing rawdata/tanh_10-7-5-4-3/epoch00000200
# Doing rawdata/tanh_10-7-5-4-3/epoch00000220
# Doing rawdata/tanh_10-7-5-4-3/epoch00000240
# Doing rawdata/tanh_10-7-5-4-3/epoch00000260
# Doing rawdata/tanh_10-7-5-4-3/epoch00000280
# Doing rawdata/tanh_10-7-5-4-3/epoch00000300
# Doing rawdata/tanh_10-7-5-4-3/epoch00000320
# Doing rawdata/tanh_10-7-5-4-3/epoch00000340
# Doing rawdata/tanh_10-7-5-4-3/epoch00000360
# Doing rawdata/tanh_10-7-5-4-3/epoch00000380
# Doing rawdata/tanh_10-7-5-4-3/epoch00000400
# Doing rawdata/tanh_10-7-5-4-3/epoch00000420
# Doing rawdata/tanh_10-7-5-4-3/epoch00000440
# Doing rawdata/tanh_10-7-5-4-3/epoch00000460
# Doing rawdata/tanh_10-7-5-4-3/epoch00000480
# Doing rawdata/tanh_10-7-5-4-3/epoch00000500
# Doing rawdata/tanh_10-7-5-4-3/epoch00000520
# Doing rawdata/tanh_10-7-5-4-3/epoch00000540
# Doing rawdata/tanh_10-7-5-4-3/epoch00000560
# Doing rawdata/tanh_10-7-5-4-3/epoch00000580
# Doing rawdata/tanh_10-7-5-4-3/epoch00000600
# Doing rawdata/tanh_10-7-5-4-3/epoch00000620
# Doing rawdata/tanh_10-7-5-4-3/epoch00000640
# Doing rawdata/tanh_10-7-5-4-3/epoch00000660
# Doing rawdata/tanh_10-7-5-4-3/epoch00000680
# Doing rawdata/tanh_10-7-5-4-3/epoch00000700
# Doing rawdata/tanh_10-7-5-4-3/epoch00000720
# Doing rawdata/tanh_10-7-5-4-3/epoch00000740
# Doing rawdata/tanh_10-7-5-4-3/epoch00000760
# Doing rawdata/tanh_10-7-5-4-3/epoch00000780
# Doing rawdata/tanh_10-7-5-4-3/epoch00000800
# Doing rawdata/tanh_10-7-5-4-3/epoch00000820
# Doing rawdata/tanh_10-7-5-4-3/epoch00000840
# Doing rawdata/tanh_10-7-5-4-3/epoch00000860
# Doing rawdata/tanh_10-7-5-4-3/epoch00000880
# Doing rawdata/tanh_10-7-5-4-3/epoch00000900
# Doing rawdata/tanh_10-7-5-4-3/epoch00000920
# Doing rawdata/tanh_10-7-5-4-3/epoch00000940
# Doing rawdata/tanh_10-7-5-4-3/epoch00000960
# Doing rawdata/tanh_10-7-5-4-3/epoch00000980
# Doing rawdata/tanh_10-7-5-4-3/epoch00001000
# Doing rawdata/tanh_10-7-5-4-3/epoch00001020
# Doing rawdata/tanh_10-7-5-4-3/epoch00001040
# Doing rawdata/tanh_10-7-5-4-3/epoch00001060
# Doing rawdata/tanh_10-7-5-4-3/epoch00001080
# Doing rawdata/tanh_10-7-5-4-3/epoch00001100
# Doing rawdata/tanh_10-7-5-4-3/epoch00001120
# Doing rawdata/tanh_10-7-5-4-3/epoch00001140
# Doing rawdata/tanh_10-7-5-4-3/epoch00001160
# Doing rawdata/tanh_10-7-5-4-3/epoch00001180
# Doing rawdata/tanh_10-7-5-4-3/epoch00001200
# Doing rawdata/tanh_10-7-5-4-3/epoch00001220
# Doing rawdata/tanh_10-7-5-4-3/epoch00001240
# Doing rawdata/tanh_10-7-5-4-3/epoch00001260
# Doing rawdata/tanh_10-7-5-4-3/epoch00001280
# Doing rawdata/tanh_10-7-5-4-3/epoch00001300
# Doing rawdata/tanh_10-7-5-4-3/epoch00001320
# Doing rawdata/tanh_10-7-5-4-3/epoch00001340
# Doing rawdata/tanh_10-7-5-4-3/epoch00001360
# Doing rawdata/tanh_10-7-5-4-3/epoch00001380
# Doing rawdata/tanh_10-7-5-4-3/epoch00001400
# Doing rawdata/tanh_10-7-5-4-3/epoch00001420
# Doing rawdata/tanh_10-7-5-4-3/epoch00001440
# Doing rawdata/tanh_10-7-5-4-3/epoch00001460
# Doing rawdata/tanh_10-7-5-4-3/epoch00001480
# Doing rawdata/tanh_10-7-5-4-3/epoch00001500
# Doing rawdata/tanh_10-7-5-4-3/epoch00001520
# Doing rawdata/tanh_10-7-5-4-3/epoch00001540
# Doing rawdata/tanh_10-7-5-4-3/epoch00001560
# Doing rawdata/tanh_10-7-5-4-3/epoch00001580
# Doing rawdata/tanh_10-7-5-4-3/epoch00001600
# Doing rawdata/tanh_10-7-5-4-3/epoch00001620
# Doing rawdata/tanh_10-7-5-4-3/epoch00001640
# Doing rawdata/tanh_10-7-5-4-3/epoch00001660
# Doing rawdata/tanh_10-7-5-4-3/epoch00001680
# Doing rawdata/tanh_10-7-5-4-3/epoch00001700
# Doing rawdata/tanh_10-7-5-4-3/epoch00001720
# Doing rawdata/tanh_10-7-5-4-3/epoch00001740
# Doing rawdata/tanh_10-7-5-4-3/epoch00001760
# Doing rawdata/tanh_10-7-5-4-3/epoch00001780
# Doing rawdata/tanh_10-7-5-4-3/epoch00001800
# Doing rawdata/tanh_10-7-5-4-3/epoch00001820
# Doing rawdata/tanh_10-7-5-4-3/epoch00001840
# Doing rawdata/tanh_10-7-5-4-3/epoch00001860
# Doing rawdata/tanh_10-7-5-4-3/epoch00001880
# Doing rawdata/tanh_10-7-5-4-3/epoch00001900
# Doing rawdata/tanh_10-7-5-4-3/epoch00001920
# Doing rawdata/tanh_10-7-5-4-3/epoch00001940
# Doing rawdata/tanh_10-7-5-4-3/epoch00001960
# Doing rawdata/tanh_10-7-5-4-3/epoch00001980
# Doing rawdata/tanh_10-7-5-4-3/epoch00002000
# Doing rawdata/tanh_10-7-5-4-3/epoch00002100
# Doing rawdata/tanh_10-7-5-4-3/epoch00002200
# Doing rawdata/tanh_10-7-5-4-3/epoch00002300
# Doing rawdata/tanh_10-7-5-4-3/epoch00002400
# Doing rawdata/tanh_10-7-5-4-3/epoch00002500
# Doing rawdata/tanh_10-7-5-4-3/epoch00002600
# Doing rawdata/tanh_10-7-5-4-3/epoch00002700
# Doing rawdata/tanh_10-7-5-4-3/epoch00002800
# Doing rawdata/tanh_10-7-5-4-3/epoch00002900
# Doing rawdata/tanh_10-7-5-4-3/epoch00003000
# Doing rawdata/tanh_10-7-5-4-3/epoch00003100
# Doing rawdata/tanh_10-7-5-4-3/epoch00003200
# Doing rawdata/tanh_10-7-5-4-3/epoch00003300
# Doing rawdata/tanh_10-7-5-4-3/epoch00003400
# Doing rawdata/tanh_10-7-5-4-3/epoch00003500
# Doing rawdata/tanh_10-7-5-4-3/epoch00003600
# Doing rawdata/tanh_10-7-5-4-3/epoch00003700
# Doing rawdata/tanh_10-7-5-4-3/epoch00003800
# Doing rawdata/tanh_10-7-5-4-3/epoch00003900
# Doing rawdata/tanh_10-7-5-4-3/epoch00004000
# Doing rawdata/tanh_10-7-5-4-3/epoch00004100
# Doing rawdata/tanh_10-7-5-4-3/epoch00004200
# Doing rawdata/tanh_10-7-5-4-3/epoch00004300
# Doing rawdata/tanh_10-7-5-4-3/epoch00004400
# Doing rawdata/tanh_10-7-5-4-3/epoch00004500
# Doing rawdata/tanh_10-7-5-4-3/epoch00004600
# Doing rawdata/tanh_10-7-5-4-3/epoch00004700
# Doing rawdata/tanh_10-7-5-4-3/epoch00004800
# Doing rawdata/tanh_10-7-5-4-3/epoch00004900
# Doing rawdata/tanh_10-7-5-4-3/epoch00005000
# Doing rawdata/tanh_10-7-5-4-3/epoch00005100
# Doing rawdata/tanh_10-7-5-4-3/epoch00005200
# Doing rawdata/tanh_10-7-5-4-3/epoch00005300
# Doing rawdata/tanh_10-7-5-4-3/epoch00005400
# Doing rawdata/tanh_10-7-5-4-3/epoch00005500
# Doing rawdata/tanh_10-7-5-4-3/epoch00005600
# Doing rawdata/tanh_10-7-5-4-3/epoch00005700
# Doing rawdata/tanh_10-7-5-4-3/epoch00005800
# Doing rawdata/tanh_10-7-5-4-3/epoch00005900
# Doing rawdata/tanh_10-7-5-4-3/epoch00006000
# Doing rawdata/tanh_10-7-5-4-3/epoch00006100
# Doing rawdata/tanh_10-7-5-4-3/epoch00006200
# Doing rawdata/tanh_10-7-5-4-3/epoch00006300
# Doing rawdata/tanh_10-7-5-4-3/epoch00006400
# Doing rawdata/tanh_10-7-5-4-3/epoch00006500
# Doing rawdata/tanh_10-7-5-4-3/epoch00006600
# Doing rawdata/tanh_10-7-5-4-3/epoch00006700
# Doing rawdata/tanh_10-7-5-4-3/epoch00006800
# Doing rawdata/tanh_10-7-5-4-3/epoch00006900
# Doing rawdata/tanh_10-7-5-4-3/epoch00007000
# Doing rawdata/tanh_10-7-5-4-3/epoch00007100
# Doing rawdata/tanh_10-7-5-4-3/epoch00007200
# Doing rawdata/tanh_10-7-5-4-3/epoch00007300
# Doing rawdata/tanh_10-7-5-4-3/epoch00007400
# Doing rawdata/tanh_10-7-5-4-3/epoch00007500
# Doing rawdata/tanh_10-7-5-4-3/epoch00007600
# Doing rawdata/tanh_10-7-5-4-3/epoch00007700
# Doing rawdata/tanh_10-7-5-4-3/epoch00007800
# Doing rawdata/tanh_10-7-5-4-3/epoch00007900
# Doing rawdata/tanh_10-7-5-4-3/epoch00008000
# Doing rawdata/tanh_10-7-5-4-3/epoch00008100
# Doing rawdata/tanh_10-7-5-4-3/epoch00008200
# Doing rawdata/tanh_10-7-5-4-3/epoch00008300
# Doing rawdata/tanh_10-7-5-4-3/epoch00008400
# Doing rawdata/tanh_10-7-5-4-3/epoch00008500
# Doing rawdata/tanh_10-7-5-4-3/epoch00008600
# Doing rawdata/tanh_10-7-5-4-3/epoch00008700
# Doing rawdata/tanh_10-7-5-4-3/epoch00008800
# Doing rawdata/tanh_10-7-5-4-3/epoch00008900
# Doing rawdata/tanh_10-7-5-4-3/epoch00009000
# Doing rawdata/tanh_10-7-5-4-3/epoch00009100
# Doing rawdata/tanh_10-7-5-4-3/epoch00009200
# Doing rawdata/tanh_10-7-5-4-3/epoch00009300
# Doing rawdata/tanh_10-7-5-4-3/epoch00009400
# Doing rawdata/tanh_10-7-5-4-3/epoch00009500
# Doing rawdata/tanh_10-7-5-4-3/epoch00009600
# Doing rawdata/tanh_10-7-5-4-3/epoch00009700
# Doing rawdata/tanh_10-7-5-4-3/epoch00009800
# Doing rawdata/tanh_10-7-5-4-3/epoch00009900
# *** Doing rawdata/relu_10-7-5-4-3 ***
# Doing rawdata/relu_10-7-5-4-3/epoch00000000
# Doing rawdata/relu_10-7-5-4-3/epoch00000001
# Doing rawdata/relu_10-7-5-4-3/epoch00000002
# Doing rawdata/relu_10-7-5-4-3/epoch00000003
# Doing rawdata/relu_10-7-5-4-3/epoch00000004
# Doing rawdata/relu_10-7-5-4-3/epoch00000005
# Doing rawdata/relu_10-7-5-4-3/epoch00000006
# Doing rawdata/relu_10-7-5-4-3/epoch00000007
# Doing rawdata/relu_10-7-5-4-3/epoch00000008
# Doing rawdata/relu_10-7-5-4-3/epoch00000009
# Doing rawdata/relu_10-7-5-4-3/epoch00000010
# Doing rawdata/relu_10-7-5-4-3/epoch00000011
# Doing rawdata/relu_10-7-5-4-3/epoch00000012
# Doing rawdata/relu_10-7-5-4-3/epoch00000013
# Doing rawdata/relu_10-7-5-4-3/epoch00000014
# Doing rawdata/relu_10-7-5-4-3/epoch00000015
# Doing rawdata/relu_10-7-5-4-3/epoch00000016
# Doing rawdata/relu_10-7-5-4-3/epoch00000017
# Doing rawdata/relu_10-7-5-4-3/epoch00000018
# Doing rawdata/relu_10-7-5-4-3/epoch00000019
# Doing rawdata/relu_10-7-5-4-3/epoch00000020
# Doing rawdata/relu_10-7-5-4-3/epoch00000025
# Doing rawdata/relu_10-7-5-4-3/epoch00000030
# Doing rawdata/relu_10-7-5-4-3/epoch00000035
# Doing rawdata/relu_10-7-5-4-3/epoch00000040
# Doing rawdata/relu_10-7-5-4-3/epoch00000045
# Doing rawdata/relu_10-7-5-4-3/epoch00000050
# Doing rawdata/relu_10-7-5-4-3/epoch00000055
# Doing rawdata/relu_10-7-5-4-3/epoch00000060
# Doing rawdata/relu_10-7-5-4-3/epoch00000065
# Doing rawdata/relu_10-7-5-4-3/epoch00000070
# Doing rawdata/relu_10-7-5-4-3/epoch00000075
# Doing rawdata/relu_10-7-5-4-3/epoch00000080
# Doing rawdata/relu_10-7-5-4-3/epoch00000085
# Doing rawdata/relu_10-7-5-4-3/epoch00000090
# Doing rawdata/relu_10-7-5-4-3/epoch00000095
# Doing rawdata/relu_10-7-5-4-3/epoch00000100
# Doing rawdata/relu_10-7-5-4-3/epoch00000120
# Doing rawdata/relu_10-7-5-4-3/epoch00000140
# Doing rawdata/relu_10-7-5-4-3/epoch00000160
# Doing rawdata/relu_10-7-5-4-3/epoch00000180
# Doing rawdata/relu_10-7-5-4-3/epoch00000200
# Doing rawdata/relu_10-7-5-4-3/epoch00000220
# Doing rawdata/relu_10-7-5-4-3/epoch00000240
# Doing rawdata/relu_10-7-5-4-3/epoch00000260
# Doing rawdata/relu_10-7-5-4-3/epoch00000280
# Doing rawdata/relu_10-7-5-4-3/epoch00000300
# Doing rawdata/relu_10-7-5-4-3/epoch00000320
# Doing rawdata/relu_10-7-5-4-3/epoch00000340
# Doing rawdata/relu_10-7-5-4-3/epoch00000360
# Doing rawdata/relu_10-7-5-4-3/epoch00000380
# Doing rawdata/relu_10-7-5-4-3/epoch00000400
# Doing rawdata/relu_10-7-5-4-3/epoch00000420
# Doing rawdata/relu_10-7-5-4-3/epoch00000440
# Doing rawdata/relu_10-7-5-4-3/epoch00000460
# Doing rawdata/relu_10-7-5-4-3/epoch00000480
# Doing rawdata/relu_10-7-5-4-3/epoch00000500
# Doing rawdata/relu_10-7-5-4-3/epoch00000520
# Doing rawdata/relu_10-7-5-4-3/epoch00000540
# Doing rawdata/relu_10-7-5-4-3/epoch00000560
# Doing rawdata/relu_10-7-5-4-3/epoch00000580
# Doing rawdata/relu_10-7-5-4-3/epoch00000600
# Doing rawdata/relu_10-7-5-4-3/epoch00000620
# Doing rawdata/relu_10-7-5-4-3/epoch00000640
# Doing rawdata/relu_10-7-5-4-3/epoch00000660
# Doing rawdata/relu_10-7-5-4-3/epoch00000680
# Doing rawdata/relu_10-7-5-4-3/epoch00000700
# Doing rawdata/relu_10-7-5-4-3/epoch00000720
# Doing rawdata/relu_10-7-5-4-3/epoch00000740
# Doing rawdata/relu_10-7-5-4-3/epoch00000760
# Doing rawdata/relu_10-7-5-4-3/epoch00000780
# Doing rawdata/relu_10-7-5-4-3/epoch00000800
# Doing rawdata/relu_10-7-5-4-3/epoch00000820
# Doing rawdata/relu_10-7-5-4-3/epoch00000840
# Doing rawdata/relu_10-7-5-4-3/epoch00000860
# Doing rawdata/relu_10-7-5-4-3/epoch00000880
# Doing rawdata/relu_10-7-5-4-3/epoch00000900
# Doing rawdata/relu_10-7-5-4-3/epoch00000920
# Doing rawdata/relu_10-7-5-4-3/epoch00000940
# Doing rawdata/relu_10-7-5-4-3/epoch00000960
# Doing rawdata/relu_10-7-5-4-3/epoch00000980
# Doing rawdata/relu_10-7-5-4-3/epoch00001000
# Doing rawdata/relu_10-7-5-4-3/epoch00001020
# Doing rawdata/relu_10-7-5-4-3/epoch00001040
# Doing rawdata/relu_10-7-5-4-3/epoch00001060
# Doing rawdata/relu_10-7-5-4-3/epoch00001080
# Doing rawdata/relu_10-7-5-4-3/epoch00001100
# Doing rawdata/relu_10-7-5-4-3/epoch00001120
# Doing rawdata/relu_10-7-5-4-3/epoch00001140
# Doing rawdata/relu_10-7-5-4-3/epoch00001160
# Doing rawdata/relu_10-7-5-4-3/epoch00001180
# Doing rawdata/relu_10-7-5-4-3/epoch00001200
# Doing rawdata/relu_10-7-5-4-3/epoch00001220
# Doing rawdata/relu_10-7-5-4-3/epoch00001240
# Doing rawdata/relu_10-7-5-4-3/epoch00001260
# Doing rawdata/relu_10-7-5-4-3/epoch00001280
# Doing rawdata/relu_10-7-5-4-3/epoch00001300
# Doing rawdata/relu_10-7-5-4-3/epoch00001320
# Doing rawdata/relu_10-7-5-4-3/epoch00001340
# Doing rawdata/relu_10-7-5-4-3/epoch00001360
# Doing rawdata/relu_10-7-5-4-3/epoch00001380
# Doing rawdata/relu_10-7-5-4-3/epoch00001400
# Doing rawdata/relu_10-7-5-4-3/epoch00001420
# Doing rawdata/relu_10-7-5-4-3/epoch00001440
# Doing rawdata/relu_10-7-5-4-3/epoch00001460
# Doing rawdata/relu_10-7-5-4-3/epoch00001480
# Doing rawdata/relu_10-7-5-4-3/epoch00001500
# Doing rawdata/relu_10-7-5-4-3/epoch00001520
# Doing rawdata/relu_10-7-5-4-3/epoch00001540
# Doing rawdata/relu_10-7-5-4-3/epoch00001560
# Doing rawdata/relu_10-7-5-4-3/epoch00001580
# Doing rawdata/relu_10-7-5-4-3/epoch00001600
# Doing rawdata/relu_10-7-5-4-3/epoch00001620
# Doing rawdata/relu_10-7-5-4-3/epoch00001640
# Doing rawdata/relu_10-7-5-4-3/epoch00001660
# Doing rawdata/relu_10-7-5-4-3/epoch00001680
# Doing rawdata/relu_10-7-5-4-3/epoch00001700
# Doing rawdata/relu_10-7-5-4-3/epoch00001720
# Doing rawdata/relu_10-7-5-4-3/epoch00001740
# Doing rawdata/relu_10-7-5-4-3/epoch00001760
# Doing rawdata/relu_10-7-5-4-3/epoch00001780
# Doing rawdata/relu_10-7-5-4-3/epoch00001800
# Doing rawdata/relu_10-7-5-4-3/epoch00001820
# Doing rawdata/relu_10-7-5-4-3/epoch00001840
# Doing rawdata/relu_10-7-5-4-3/epoch00001860
# Doing rawdata/relu_10-7-5-4-3/epoch00001880
# Doing rawdata/relu_10-7-5-4-3/epoch00001900
# Doing rawdata/relu_10-7-5-4-3/epoch00001920
# Doing rawdata/relu_10-7-5-4-3/epoch00001940
# Doing rawdata/relu_10-7-5-4-3/epoch00001960
# Doing rawdata/relu_10-7-5-4-3/epoch00001980
# Doing rawdata/relu_10-7-5-4-3/epoch00002000
# Doing rawdata/relu_10-7-5-4-3/epoch00002100
# Doing rawdata/relu_10-7-5-4-3/epoch00002200
# Doing rawdata/relu_10-7-5-4-3/epoch00002300
# Doing rawdata/relu_10-7-5-4-3/epoch00002400
# Doing rawdata/relu_10-7-5-4-3/epoch00002500
# Doing rawdata/relu_10-7-5-4-3/epoch00002600
# Doing rawdata/relu_10-7-5-4-3/epoch00002700
# Doing rawdata/relu_10-7-5-4-3/epoch00002800
# Doing rawdata/relu_10-7-5-4-3/epoch00002900
# Doing rawdata/relu_10-7-5-4-3/epoch00003000
# Doing rawdata/relu_10-7-5-4-3/epoch00003100
# Doing rawdata/relu_10-7-5-4-3/epoch00003200
# Doing rawdata/relu_10-7-5-4-3/epoch00003300
# Doing rawdata/relu_10-7-5-4-3/epoch00003400
# Doing rawdata/relu_10-7-5-4-3/epoch00003500
# Doing rawdata/relu_10-7-5-4-3/epoch00003600
# Doing rawdata/relu_10-7-5-4-3/epoch00003700
# Doing rawdata/relu_10-7-5-4-3/epoch00003800
# Doing rawdata/relu_10-7-5-4-3/epoch00003900
# Doing rawdata/relu_10-7-5-4-3/epoch00004000
# Doing rawdata/relu_10-7-5-4-3/epoch00004100
# Doing rawdata/relu_10-7-5-4-3/epoch00004200
# Doing rawdata/relu_10-7-5-4-3/epoch00004300
# Doing rawdata/relu_10-7-5-4-3/epoch00004400
# Doing rawdata/relu_10-7-5-4-3/epoch00004500
# Doing rawdata/relu_10-7-5-4-3/epoch00004600
# Doing rawdata/relu_10-7-5-4-3/epoch00004700
# Doing rawdata/relu_10-7-5-4-3/epoch00004800
# Doing rawdata/relu_10-7-5-4-3/epoch00004900
# Doing rawdata/relu_10-7-5-4-3/epoch00005000
# Doing rawdata/relu_10-7-5-4-3/epoch00005100
# Doing rawdata/relu_10-7-5-4-3/epoch00005200
# Doing rawdata/relu_10-7-5-4-3/epoch00005300
# Doing rawdata/relu_10-7-5-4-3/epoch00005400
# Doing rawdata/relu_10-7-5-4-3/epoch00005500
# Doing rawdata/relu_10-7-5-4-3/epoch00005600
# Doing rawdata/relu_10-7-5-4-3/epoch00005700
# Doing rawdata/relu_10-7-5-4-3/epoch00005800
# Doing rawdata/relu_10-7-5-4-3/epoch00005900
# Doing rawdata/relu_10-7-5-4-3/epoch00006000
# Doing rawdata/relu_10-7-5-4-3/epoch00006100
# Doing rawdata/relu_10-7-5-4-3/epoch00006200
# Doing rawdata/relu_10-7-5-4-3/epoch00006300
# Doing rawdata/relu_10-7-5-4-3/epoch00006400
# Doing rawdata/relu_10-7-5-4-3/epoch00006500
# Doing rawdata/relu_10-7-5-4-3/epoch00006600
# Doing rawdata/relu_10-7-5-4-3/epoch00006700
# Doing rawdata/relu_10-7-5-4-3/epoch00006800
# Doing rawdata/relu_10-7-5-4-3/epoch00006900
# Doing rawdata/relu_10-7-5-4-3/epoch00007000
# Doing rawdata/relu_10-7-5-4-3/epoch00007100
# Doing rawdata/relu_10-7-5-4-3/epoch00007200
# Doing rawdata/relu_10-7-5-4-3/epoch00007300
# Doing rawdata/relu_10-7-5-4-3/epoch00007400
# Doing rawdata/relu_10-7-5-4-3/epoch00007500
# Doing rawdata/relu_10-7-5-4-3/epoch00007600
# Doing rawdata/relu_10-7-5-4-3/epoch00007700
# Doing rawdata/relu_10-7-5-4-3/epoch00007800
# Doing rawdata/relu_10-7-5-4-3/epoch00007900
# Doing rawdata/relu_10-7-5-4-3/epoch00008000
# Doing rawdata/relu_10-7-5-4-3/epoch00008100
# Doing rawdata/relu_10-7-5-4-3/epoch00008200
# Doing rawdata/relu_10-7-5-4-3/epoch00008300
# Doing rawdata/relu_10-7-5-4-3/epoch00008400
# Doing rawdata/relu_10-7-5-4-3/epoch00008500
# Doing rawdata/relu_10-7-5-4-3/epoch00008600
# Doing rawdata/relu_10-7-5-4-3/epoch00008700
# Doing rawdata/relu_10-7-5-4-3/epoch00008800
# Doing rawdata/relu_10-7-5-4-3/epoch00008900
# Doing rawdata/relu_10-7-5-4-3/epoch00009000
# Doing rawdata/relu_10-7-5-4-3/epoch00009100
# Doing rawdata/relu_10-7-5-4-3/epoch00009200
# Doing rawdata/relu_10-7-5-4-3/epoch00009300
# Doing rawdata/relu_10-7-5-4-3/epoch00009400
# Doing rawdata/relu_10-7-5-4-3/epoch00009500
# Doing rawdata/relu_10-7-5-4-3/epoch00009600
# Doing rawdata/relu_10-7-5-4-3/epoch00009700
# Doing rawdata/relu_10-7-5-4-3/epoch00009800
# Doing rawdata/relu_10-7-5-4-3/epoch00009900
# *** Doing rawdata/linear_10-7-5-4-3 ***
# Doing rawdata/linear_10-7-5-4-3/epoch00000000
# Doing rawdata/linear_10-7-5-4-3/epoch00000001
# Doing rawdata/linear_10-7-5-4-3/epoch00000002
# Doing rawdata/linear_10-7-5-4-3/epoch00000003
# Doing rawdata/linear_10-7-5-4-3/epoch00000004
# Doing rawdata/linear_10-7-5-4-3/epoch00000005
# Doing rawdata/linear_10-7-5-4-3/epoch00000006
# Doing rawdata/linear_10-7-5-4-3/epoch00000007
# Doing rawdata/linear_10-7-5-4-3/epoch00000008
# Doing rawdata/linear_10-7-5-4-3/epoch00000009
# Doing rawdata/linear_10-7-5-4-3/epoch00000010
# Doing rawdata/linear_10-7-5-4-3/epoch00000011
# Doing rawdata/linear_10-7-5-4-3/epoch00000012
# Doing rawdata/linear_10-7-5-4-3/epoch00000013
# Doing rawdata/linear_10-7-5-4-3/epoch00000014
# Doing rawdata/linear_10-7-5-4-3/epoch00000015
# Doing rawdata/linear_10-7-5-4-3/epoch00000016
# Doing rawdata/linear_10-7-5-4-3/epoch00000017
# Doing rawdata/linear_10-7-5-4-3/epoch00000018
# Doing rawdata/linear_10-7-5-4-3/epoch00000019
# Doing rawdata/linear_10-7-5-4-3/epoch00000020
# Doing rawdata/linear_10-7-5-4-3/epoch00000025
# Doing rawdata/linear_10-7-5-4-3/epoch00000030
# Doing rawdata/linear_10-7-5-4-3/epoch00000035
# Doing rawdata/linear_10-7-5-4-3/epoch00000040
# Doing rawdata/linear_10-7-5-4-3/epoch00000045
# Doing rawdata/linear_10-7-5-4-3/epoch00000050
# Doing rawdata/linear_10-7-5-4-3/epoch00000055
# Doing rawdata/linear_10-7-5-4-3/epoch00000060
# Doing rawdata/linear_10-7-5-4-3/epoch00000065
# Doing rawdata/linear_10-7-5-4-3/epoch00000070
# Doing rawdata/linear_10-7-5-4-3/epoch00000075
# Doing rawdata/linear_10-7-5-4-3/epoch00000080
# Doing rawdata/linear_10-7-5-4-3/epoch00000085
# Doing rawdata/linear_10-7-5-4-3/epoch00000090
# Doing rawdata/linear_10-7-5-4-3/epoch00000095
# Doing rawdata/linear_10-7-5-4-3/epoch00000100
# Doing rawdata/linear_10-7-5-4-3/epoch00000120
# Doing rawdata/linear_10-7-5-4-3/epoch00000140
# Doing rawdata/linear_10-7-5-4-3/epoch00000160
# Doing rawdata/linear_10-7-5-4-3/epoch00000180
# Doing rawdata/linear_10-7-5-4-3/epoch00000200
# Doing rawdata/linear_10-7-5-4-3/epoch00000220
# Doing rawdata/linear_10-7-5-4-3/epoch00000240
# Doing rawdata/linear_10-7-5-4-3/epoch00000260
# Doing rawdata/linear_10-7-5-4-3/epoch00000280
# Doing rawdata/linear_10-7-5-4-3/epoch00000300
# Doing rawdata/linear_10-7-5-4-3/epoch00000320
# Doing rawdata/linear_10-7-5-4-3/epoch00000340
# Doing rawdata/linear_10-7-5-4-3/epoch00000360
# Doing rawdata/linear_10-7-5-4-3/epoch00000380
# Doing rawdata/linear_10-7-5-4-3/epoch00000400
# Doing rawdata/linear_10-7-5-4-3/epoch00000420
# Doing rawdata/linear_10-7-5-4-3/epoch00000440
# Doing rawdata/linear_10-7-5-4-3/epoch00000460
# Doing rawdata/linear_10-7-5-4-3/epoch00000480
# Doing rawdata/linear_10-7-5-4-3/epoch00000500
# Doing rawdata/linear_10-7-5-4-3/epoch00000520
# Doing rawdata/linear_10-7-5-4-3/epoch00000540
# Doing rawdata/linear_10-7-5-4-3/epoch00000560
# Doing rawdata/linear_10-7-5-4-3/epoch00000580
# Doing rawdata/linear_10-7-5-4-3/epoch00000600
# Doing rawdata/linear_10-7-5-4-3/epoch00000620
# Doing rawdata/linear_10-7-5-4-3/epoch00000640
# Doing rawdata/linear_10-7-5-4-3/epoch00000660
# Doing rawdata/linear_10-7-5-4-3/epoch00000680
# Doing rawdata/linear_10-7-5-4-3/epoch00000700
# Doing rawdata/linear_10-7-5-4-3/epoch00000720
# Doing rawdata/linear_10-7-5-4-3/epoch00000740
# Doing rawdata/linear_10-7-5-4-3/epoch00000760
# Doing rawdata/linear_10-7-5-4-3/epoch00000780
# Doing rawdata/linear_10-7-5-4-3/epoch00000800
# Doing rawdata/linear_10-7-5-4-3/epoch00000820
# Doing rawdata/linear_10-7-5-4-3/epoch00000840
# Doing rawdata/linear_10-7-5-4-3/epoch00000860
# Doing rawdata/linear_10-7-5-4-3/epoch00000880
# Doing rawdata/linear_10-7-5-4-3/epoch00000900
# Doing rawdata/linear_10-7-5-4-3/epoch00000920
# Doing rawdata/linear_10-7-5-4-3/epoch00000940
# Doing rawdata/linear_10-7-5-4-3/epoch00000960
# Doing rawdata/linear_10-7-5-4-3/epoch00000980
# Doing rawdata/linear_10-7-5-4-3/epoch00001000
# Doing rawdata/linear_10-7-5-4-3/epoch00001020
# Doing rawdata/linear_10-7-5-4-3/epoch00001040
# Doing rawdata/linear_10-7-5-4-3/epoch00001060
# Doing rawdata/linear_10-7-5-4-3/epoch00001080
# Doing rawdata/linear_10-7-5-4-3/epoch00001100
# Doing rawdata/linear_10-7-5-4-3/epoch00001120
# Doing rawdata/linear_10-7-5-4-3/epoch00001140
# Doing rawdata/linear_10-7-5-4-3/epoch00001160
# Doing rawdata/linear_10-7-5-4-3/epoch00001180
# Doing rawdata/linear_10-7-5-4-3/epoch00001200
# Doing rawdata/linear_10-7-5-4-3/epoch00001220
# Doing rawdata/linear_10-7-5-4-3/epoch00001240
# Doing rawdata/linear_10-7-5-4-3/epoch00001260
# Doing rawdata/linear_10-7-5-4-3/epoch00001280
# Doing rawdata/linear_10-7-5-4-3/epoch00001300
# Doing rawdata/linear_10-7-5-4-3/epoch00001320
# Doing rawdata/linear_10-7-5-4-3/epoch00001340
# Doing rawdata/linear_10-7-5-4-3/epoch00001360
# Doing rawdata/linear_10-7-5-4-3/epoch00001380
# Doing rawdata/linear_10-7-5-4-3/epoch00001400
# Doing rawdata/linear_10-7-5-4-3/epoch00001420
# Doing rawdata/linear_10-7-5-4-3/epoch00001440
# Doing rawdata/linear_10-7-5-4-3/epoch00001460
# Doing rawdata/linear_10-7-5-4-3/epoch00001480
# Doing rawdata/linear_10-7-5-4-3/epoch00001500
# Doing rawdata/linear_10-7-5-4-3/epoch00001520
# Doing rawdata/linear_10-7-5-4-3/epoch00001540
# Doing rawdata/linear_10-7-5-4-3/epoch00001560
# Doing rawdata/linear_10-7-5-4-3/epoch00001580
# Doing rawdata/linear_10-7-5-4-3/epoch00001600
# Doing rawdata/linear_10-7-5-4-3/epoch00001620
# Doing rawdata/linear_10-7-5-4-3/epoch00001640
# Doing rawdata/linear_10-7-5-4-3/epoch00001660
# Doing rawdata/linear_10-7-5-4-3/epoch00001680
# Doing rawdata/linear_10-7-5-4-3/epoch00001700
# Doing rawdata/linear_10-7-5-4-3/epoch00001720
# Doing rawdata/linear_10-7-5-4-3/epoch00001740
# Doing rawdata/linear_10-7-5-4-3/epoch00001760
# Doing rawdata/linear_10-7-5-4-3/epoch00001780
# Doing rawdata/linear_10-7-5-4-3/epoch00001800
# Doing rawdata/linear_10-7-5-4-3/epoch00001820
# Doing rawdata/linear_10-7-5-4-3/epoch00001840
# Doing rawdata/linear_10-7-5-4-3/epoch00001860
# Doing rawdata/linear_10-7-5-4-3/epoch00001880
# Doing rawdata/linear_10-7-5-4-3/epoch00001900
# Doing rawdata/linear_10-7-5-4-3/epoch00001920
# Doing rawdata/linear_10-7-5-4-3/epoch00001940
# Doing rawdata/linear_10-7-5-4-3/epoch00001960
# Doing rawdata/linear_10-7-5-4-3/epoch00001980
# Doing rawdata/linear_10-7-5-4-3/epoch00002000
# Doing rawdata/linear_10-7-5-4-3/epoch00002100
# Doing rawdata/linear_10-7-5-4-3/epoch00002200
# Doing rawdata/linear_10-7-5-4-3/epoch00002300
# Doing rawdata/linear_10-7-5-4-3/epoch00002400
# Doing rawdata/linear_10-7-5-4-3/epoch00002500
# Doing rawdata/linear_10-7-5-4-3/epoch00002600
# Doing rawdata/linear_10-7-5-4-3/epoch00002700
# Doing rawdata/linear_10-7-5-4-3/epoch00002800
# Doing rawdata/linear_10-7-5-4-3/epoch00002900
# Doing rawdata/linear_10-7-5-4-3/epoch00003000
# Doing rawdata/linear_10-7-5-4-3/epoch00003100
# Doing rawdata/linear_10-7-5-4-3/epoch00003200
# Doing rawdata/linear_10-7-5-4-3/epoch00003300
# Doing rawdata/linear_10-7-5-4-3/epoch00003400
# Doing rawdata/linear_10-7-5-4-3/epoch00003500
# Doing rawdata/linear_10-7-5-4-3/epoch00003600
# Doing rawdata/linear_10-7-5-4-3/epoch00003700
# Doing rawdata/linear_10-7-5-4-3/epoch00003800
# Doing rawdata/linear_10-7-5-4-3/epoch00003900
# Doing rawdata/linear_10-7-5-4-3/epoch00004000
# Doing rawdata/linear_10-7-5-4-3/epoch00004100
# Doing rawdata/linear_10-7-5-4-3/epoch00004200
# Doing rawdata/linear_10-7-5-4-3/epoch00004300
# Doing rawdata/linear_10-7-5-4-3/epoch00004400
# Doing rawdata/linear_10-7-5-4-3/epoch00004500
# Doing rawdata/linear_10-7-5-4-3/epoch00004600
# Doing rawdata/linear_10-7-5-4-3/epoch00004700
# Doing rawdata/linear_10-7-5-4-3/epoch00004800
# Doing rawdata/linear_10-7-5-4-3/epoch00004900
# Doing rawdata/linear_10-7-5-4-3/epoch00005000
# Doing rawdata/linear_10-7-5-4-3/epoch00005100
# Doing rawdata/linear_10-7-5-4-3/epoch00005200
# Doing rawdata/linear_10-7-5-4-3/epoch00005300
# Doing rawdata/linear_10-7-5-4-3/epoch00005400
# Doing rawdata/linear_10-7-5-4-3/epoch00005500
# Doing rawdata/linear_10-7-5-4-3/epoch00005600
# Doing rawdata/linear_10-7-5-4-3/epoch00005700
# Doing rawdata/linear_10-7-5-4-3/epoch00005800
# Doing rawdata/linear_10-7-5-4-3/epoch00005900
# Doing rawdata/linear_10-7-5-4-3/epoch00006000
# Doing rawdata/linear_10-7-5-4-3/epoch00006100
# Doing rawdata/linear_10-7-5-4-3/epoch00006200
# Doing rawdata/linear_10-7-5-4-3/epoch00006300
# Doing rawdata/linear_10-7-5-4-3/epoch00006400
# Doing rawdata/linear_10-7-5-4-3/epoch00006500
# Doing rawdata/linear_10-7-5-4-3/epoch00006600
# Doing rawdata/linear_10-7-5-4-3/epoch00006700
# Doing rawdata/linear_10-7-5-4-3/epoch00006800
# Doing rawdata/linear_10-7-5-4-3/epoch00006900
# Doing rawdata/linear_10-7-5-4-3/epoch00007000
# Doing rawdata/linear_10-7-5-4-3/epoch00007100
# Doing rawdata/linear_10-7-5-4-3/epoch00007200
# Doing rawdata/linear_10-7-5-4-3/epoch00007300
# Doing rawdata/linear_10-7-5-4-3/epoch00007400
# Doing rawdata/linear_10-7-5-4-3/epoch00007500
# Doing rawdata/linear_10-7-5-4-3/epoch00007600
# Doing rawdata/linear_10-7-5-4-3/epoch00007700
# Doing rawdata/linear_10-7-5-4-3/epoch00007800
# Doing rawdata/linear_10-7-5-4-3/epoch00007900
# Doing rawdata/linear_10-7-5-4-3/epoch00008000
# Doing rawdata/linear_10-7-5-4-3/epoch00008100
# Doing rawdata/linear_10-7-5-4-3/epoch00008200
# Doing rawdata/linear_10-7-5-4-3/epoch00008300
# Doing rawdata/linear_10-7-5-4-3/epoch00008400
# Doing rawdata/linear_10-7-5-4-3/epoch00008500
# Doing rawdata/linear_10-7-5-4-3/epoch00008600
# Doing rawdata/linear_10-7-5-4-3/epoch00008700
# Doing rawdata/linear_10-7-5-4-3/epoch00008800
# Doing rawdata/linear_10-7-5-4-3/epoch00008900
# Doing rawdata/linear_10-7-5-4-3/epoch00009000
# Doing rawdata/linear_10-7-5-4-3/epoch00009100
# Doing rawdata/linear_10-7-5-4-3/epoch00009200
# Doing rawdata/linear_10-7-5-4-3/epoch00009300
# Doing rawdata/linear_10-7-5-4-3/epoch00009400
# Doing rawdata/linear_10-7-5-4-3/epoch00009500
# Doing rawdata/linear_10-7-5-4-3/epoch00009600
# Doing rawdata/linear_10-7-5-4-3/epoch00009700
# Doing rawdata/linear_10-7-5-4-3/epoch00009800
# Doing rawdata/linear_10-7-5-4-3/epoch00009900
# *** Doing rawdata/linear_Batch_10-7-5-4-3 ***
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000001
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000002
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000003
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000004
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000005
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000006
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000007
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000008
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000009
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000010
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000011
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000012
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000013
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000014
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000015
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000016
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000017
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000018
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000019
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000020
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000025
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000030
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000035
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000040
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000045
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000050
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000055
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000060
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000065
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000070
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000075
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000080
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000085
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000090
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000095
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000120
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000140
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000160
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000180
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000220
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000240
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000260
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000280
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000320
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000340
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000360
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000380
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000420
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000440
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000460
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000480
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000520
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000540
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000560
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000580
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000620
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000640
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000660
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000680
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000720
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000740
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000760
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000780
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000820
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000840
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000860
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000880
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000920
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000940
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000960
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00000980
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001020
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001040
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001060
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001080
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001120
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001140
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001160
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001180
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001220
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001240
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001260
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001280
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001320
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001340
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001360
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001380
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001420
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001440
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001460
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001480
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001520
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001540
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001560
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001580
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001620
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001640
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001660
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001680
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001720
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001740
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001760
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001780
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001820
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001840
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001860
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001880
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001920
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001940
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001960
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00001980
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00002900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00003900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00004900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00005900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00006900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00007900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00008900
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009000
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009100
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009200
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009300
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009400
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009500
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009600
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009700
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009800
# Doing rawdata/linear_Batch_10-7-5-4-3/epoch00009900

# %% [markdown]
# Plot Infoplane Visualization
# ----

# %%
max_epoch = max( (max(vals.keys()) if len(vals) else 0) for vals in measures.values())
sm = plt.cm.ScalarMappable(cmap='gnuplot', norm=plt.Normalize(vmin=0, vmax=COLORBAR_MAX_EPOCHS))
sm._A = []

fig=plt.figure(figsize=(10,5))
for actndx, (activation, vals) in enumerate(measures.items()):
    epochs = sorted(vals.keys())
    if not len(epochs):
        continue
    plt.subplot(1,2,actndx+1)    
    for epoch in epochs:
        c = sm.to_rgba(epoch)
        xmvals = np.array(vals[epoch]['MI_XM_'+infoplane_measure])[PLOT_LAYERS]
        ymvals = np.array(vals[epoch]['MI_YM_'+infoplane_measure])[PLOT_LAYERS]

        plt.plot(xmvals, ymvals, c=c, alpha=0.1, zorder=1)
        plt.scatter(xmvals, ymvals, s=20, facecolors=[c for _ in PLOT_LAYERS], edgecolor='none', zorder=2)

    plt.ylim([0, 1])
    plt.xlim([0, 12])
#     plt.ylim([0, 3.5])
#     plt.xlim([0, 14])
    plt.xlabel('I(X;M)')
    plt.ylabel('I(Y;M)')
    plt.title(activation)
    
cbaxes = fig.add_axes([1.0, 0.125, 0.03, 0.8]) 
plt.colorbar(sm, label='Epoch', cax=cbaxes)
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('infoplane_'+ARCH),bbox_inches='tight')
# Out:
# <ipython-input-9-eaecca735d53>:29: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()

# %% [markdown]
# Plot SNR curves
# ----

# %%
plt.figure(figsize=(12,5))

gs = gridspec.GridSpec(len(measures), len(PLOT_LAYERS))
for activation in measures.keys():
    cur_dir = 'rawdata/' + DIR_TEMPLATE % activation
    if not os.path.exists(cur_dir):
        continue
        
    epochs = []
    means = []
    stds = []
    wnorms = []
    for epochfile in sorted(os.listdir(cur_dir)):
        if not epochfile.startswith('epoch'):
            continue
            
        with open(cur_dir + "/"+epochfile, 'rb') as f:
            d = cPickle.load(f)
            
        epoch = d['epoch']
        epochs.append(epoch)
        wnorms.append(d['data']['weights_norm'])
        means.append(d['data']['gradmean'])
        stds.append(d['data']['gradstd'])

    wnorms, means, stds = map(np.array, [wnorms, means, stds])
    for lndx,layerid in enumerate(PLOT_LAYERS):
        plt.subplot(gs[actndx, lndx])
        plt.plot(epochs, means[:,layerid], 'b', label="Mean")
        plt.plot(epochs, stds[:,layerid], 'orange', label="Std")
        plt.plot(epochs, means[:,layerid]/stds[:,layerid], 'red', label="SNR")
        plt.plot(epochs, wnorms[:,layerid], 'g', label="||W||")

        plt.title('Layer %d'%layerid)
        plt.xlabel('Epoch')
        plt.gca().set_xscale("log", nonposx='clip')
        plt.gca().set_yscale("log", nonposy='clip')
    

plt.legend(loc='lower left', bbox_to_anchor=(1.1, 0.2))
plt.tight_layout()

if DO_SAVE:
    plt.savefig('plots/' + DIR_TEMPLATE % ('snr_'+ARCH), bbox_inches='tight')
# Out:
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
# <ipython-input-10-2cece08e2dd3>:36: MatplotlibDeprecationWarning: The 'nonposx' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_xscale("log", nonposx='clip')
# <ipython-input-10-2cece08e2dd3>:37: MatplotlibDeprecationWarning: The 'nonposy' parameter of __init__() has been renamed 'nonpositive' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   plt.gca().set_yscale("log", nonposy='clip')
